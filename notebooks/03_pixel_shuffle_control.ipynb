# %% [markdown]
# # Phase I: Pixel Shuffle Control
#
# **Status**: COMPLETE
# **Colab Link**: [Open in Colab](https://colab.research.google.com/drive/19qUlvA5l7vMswTg0psYmb-Iw6IEFboEs?usp=drive_link)
#
# ## Description
# Validation of the data-dependency of functional geometry. This notebook explores activation manifolds in networks trained on pixel-shuffled data, where local spatial correlations have been destroyed. This is used to test if manifolds encode task-relevant data structure.
#
# ## Supporting Material
# - Script: `scripts/neuro_cartographer.py`
