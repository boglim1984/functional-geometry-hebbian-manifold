# %% [markdown]
# # Phase III: Neuro-Surgeon Biopsy v2 (Successful Single-Pair)
#
# **Status**: COMPLETE
# **Colab Link**: [Open in Colab](https://colab.research.google.com/drive/110sO1CQ5d8Worg3PrXJY2nmGgRtbdR5M?usp=drive_link)
#
# ## Description
# Refined causal intervention demonstrating that merging geometrically proximal neurons preserves model function. This notebook provides the primary evidence for the 'local merges are safe' hypothesis.
#
# ## Supporting Material
# - Script: `scripts/neuro_surgeon.py`
