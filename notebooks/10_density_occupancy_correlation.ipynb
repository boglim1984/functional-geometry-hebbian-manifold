# %% [markdown]
# # Experiment 2: Density–Occupancy Correlation
#
# **Status**: COMPLETE
# **Colab Link**: [Open in Colab](https://colab.research.google.com/drive/15keQSvznJ6HUIk13WlWuGyxElHO1iiLA?usp=drive_link)
#
# ## Description
# Topological characterization of high-variance traversal pathways. Confirms that these "highways" preferentially inhabit dense cluster cores ("backbones") rather than sparse boundary regions of the latent manifold.
