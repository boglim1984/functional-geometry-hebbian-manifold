# %% [markdown]
# # Phase II - Experiment 2: Training Objective Geometry Test (Preliminary)
#
# **Status**: PRELIMINARY / EXPLORATORY
# **Colab Link**: [Open in Colab](https://colab.research.google.com/drive/1IsUGxfQUs4cXr5NIrGnR0B6TyznAZt2q?usp=sharing)
#
# ## Description
# Exploratory investigation into the "Collapse Hypothesis". Compares local geometric structure between supervised (cross-entropy) and self-supervised (contrastive) representations. Preliminary results suggest that contrastive objectives may preserve local linear fibers that are collapsed under supervised training.
