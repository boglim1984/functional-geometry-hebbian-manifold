# %% [markdown]
# # Phase II: Neuro-Surgeon Biopsy (FAILED/DIAGNOSTIC)
#
# **Status**: FAILED / DIAGNOSTIC — DO NOT USE FOR CONCLUSIONS
# **Colab Link**: [Open in Colab](https://colab.research.google.com/drive/110sO1CQ5d8Worg3PrXJY2nmGgRtbdR5M?usp=drive_link)
#
# ## Description
# Initial causal intervention attempt. This notebook documents unsuccessful merges where geometric proximity failed to preserve model performance. Critical for understanding the limitations of the consolidation prior and identifying architectural edge cases.
#
# ## Supporting Material
# - Script: `scripts/neuro_surgeon.py`
