# %% [markdown]
# # Experiment 3: Vector Field Alignment
#
# **Status**: COMPLETE
# **Colab Link**: [Open in Colab](https://colab.research.google.com/drive/1aQNVJru_8MLIA3wjxUEHmAFs2LmAzeco?usp=sharing)
#
# ## Description
# Investigation into the local geometric linearity of dense latent backbones. Confirms that these regions are internally isotropic rather than composed of coherent low-dimensional fibers at the scale tested.
