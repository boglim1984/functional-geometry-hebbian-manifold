# %% [markdown]
# # Metric-Aware Walker Probe Study
#
# **Status**: COMPLETE
# **Colab Link**: [Open in Colab](https://colab.research.google.com/drive/1zGZH1utq38y4G9RjYEchbuF2ObB_WDTX?usp=drive_link)
#
# ## Description
# Evaluation of the upgraded metric-aware + short-memory walker (Instrument I₁). Demonstrates reduced probe-induced looping, increased trajectory diversity, and more coherent traversal of the ResNet latent space compared to the baseline random walker (Instrument I₀).
