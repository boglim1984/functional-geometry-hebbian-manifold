# %% [markdown]
# # Phase I: Neuro-Cartography (Primary Map Creation)
#
# **Status**: COMPLETE
# **Colab Link**: [Open in Colab](https://colab.research.google.com/drive/1Fq1l2yQtmzHF7zrIWcXd_1iyKWYtFNm6?usp=drive_link)
#
# ## Description
# Initial discovery and mapping of functional geometry in trained ResNet-18 models. This notebook implements the activation extraction, UMAP reduction, and 3D point cloud generation for trained layers.
#
# ## Supporting Material
# - Script: `scripts/neuro_cartographer.py`
