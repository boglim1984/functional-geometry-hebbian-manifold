# %% [markdown]
# # Phase II - Experiment 3: Trajectory Spectrum Test (Manifold Persistence)
#
# **Status**: PROVISIONAL / INTERPRETIVE
# **Colab Link**: [Open in Colab](https://colab.research.google.com/drive/1vitpfyNbuNAPW3LfDGAVHjHH0eMzNICu?usp=sharing)
#
# ## Description
# Tests whether latent-space alignment in SSL models aggregates into coherent 1D manifolds (fibers) or reflects low-rank dimensional collapse (flattening). Measures PC1 Explained Variance Ratio (EVR₁) over sliding windows (L=20). Results indicate higher persistence in SSL compared to supervised models, but suggest a "slab-like" geometry rather than disentangled fibers.
