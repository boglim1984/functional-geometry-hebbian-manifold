# %% [markdown]
# # Phase II - Experiment 1: Scale-Dependent Linearity Test
#
# **Status**: COMPLETE
# **Colab Link**: [Open in Colab](https://colab.research.google.com/drive/1FEeB_0vdZWQO6qF4784s-_h2hA6YKs96?usp=sharing)
#
# ## Description
# Tests whether latent-space isotropy is a scale artifact by estimating local tangents over multiple neighborhood scales (k=10 to k=500). Confirms that ResNet18 latent backbones remain internally isotropic across all tested scales.
