# %% [markdown]
# # Phase III: Neuro-Surgeon Batch Biopsy (Statistical Validation)
#
# **Status**: COMPLETE
# **Colab Link**: [Open in Colab](https://colab.research.google.com/drive/1bxQ-ZOA6lep-b2QhyvM71dj5zt1YI7vc?usp=drive_link)
#
# ## Description
# Large-scale statistical validation of geometry-guided consolidation. This notebook performs multiple independent interventions across different layers to confirm the scalability and reliability of functional geometry as a compression prior.
#
# ## Supporting Material
# - Script: `scripts/neuro_surgeon_batch.py`
